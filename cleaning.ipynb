# %%
import pandas as pd 
import os 
import shutil 
from pathlib import Path
from glob import glob
import librosa
import librosa.display
from IPython.display import Audio

# %% [markdown]
# Load and Play audio

# %%
## let's create a path object and load the dataset from the specified directory
review_files=glob('../Data_Music/genres_original/reggae/*.wav')

# %%
counter =0
for file in review_files:
    print(file, counter)
    counter+=1
# Out:
# ../Data_Music/genres_original/reggae/reggae.00080.wav 0
# ../Data_Music/genres_original/reggae/reggae.00094.wav 1
# ../Data_Music/genres_original/reggae/reggae.00043.wav 2
# ../Data_Music/genres_original/reggae/reggae.00057.wav 3
# ../Data_Music/genres_original/reggae/reggae.00056.wav 4
# ../Data_Music/genres_original/reggae/reggae.00042.wav 5
# ../Data_Music/genres_original/reggae/reggae.00095.wav 6
# ../Data_Music/genres_original/reggae/reggae.00081.wav 7
# ../Data_Music/genres_original/reggae/reggae.00097.wav 8
# ../Data_Music/genres_original/reggae/reggae.00083.wav 9
# ../Data_Music/genres_original/reggae/reggae.00054.wav 10
# ../Data_Music/genres_original/reggae/reggae.00040.wav 11
# ../Data_Music/genres_original/reggae/reggae.00068.wav 12
# ../Data_Music/genres_original/reggae/reggae.00069.wav 13
# ../Data_Music/genres_original/reggae/reggae.00041.wav 14
# ../Data_Music/genres_original/reggae/reggae.00055.wav 15
# ../Data_Music/genres_original/reggae/reggae.00082.wav 16
# ...

# %% [markdown]
# def load_audio(file_path):
#     audio, sample_rate = librosa.load(review_files[0])
#     return audio, sample_rate

# %%
#load the file using librosa; this will load the audio file and return the audio time series and the sample rate
audio,sr =librosa.load(review_files[1])

# %%
#play the loaded file; listen to audio to see if it has sound
Audio(audio, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# I am going to try to make an iterative loop through all the songs to see if it can listen

# %% [markdown]
# https://www.geeksforgeeks.org/deep-learning/repeating-tensors-in-a-specific-new-dimension-in-pytorch/
# - repeating the tensor with multiple dimensions .
# Duplicating the single channel to 3 channels so ImageNet stem weights are usable as intended

# %%
import os
import copy
import time
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
#import torchvision.models as models

from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = True

# %%
print(train_df.shape, val_df.shape, test_df.shape)
print(train_df.columns)
print(train_df['label'].value_counts().sort_index())

# %%
genre_to_idx = {genre: i for i, genre in enumerate(sorted(train_df['label'].unique()))}
idx_to_genre = {v: k for k, v in genre_to_idx.items()}

num_classes = len(genre_to_idx)
print("Number of classes:", num_classes)
print("Label map:", genre_to_idx)
